# %% [markdown]
# <a href="https://colab.research.google.com/github/Tiabet/Python_Study/blob/master/Movie_review_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import ast

file_path = '영화리뷰.csv'
reviews_df = pd.read_csv(file_path)

reviews_df = reviews_df.dropna(subset=['reviews'])

reviews_df['reviews'] = reviews_df['reviews'].apply(ast.literal_eval)

# Explode the dataframe to create one row per review
expanded_reviews_df = reviews_df.explode('reviews').reset_index(drop=True)

# Display the first few rows of the new dataframe
print(expanded_reviews_df.head())

# Save the expanded dataframe to a new CSV file
expanded_reviews_df.to_csv('/영화리뷰_왓챠피디아_확장.csv', index=False)
# Out:
#    title  rating                                            reviews
# 0  서울의 봄     3.9                                하아 대머리 죽었지만 다시 죽이고픔
# 1  서울의 봄     3.9       야만과 무능의 그 겨울밤에 대한 분노가 시종 팽팽한 긴장감 속에서 펄펄 끓는다.
# 2  서울의 봄     3.9                                   예정된 비극을 바라보는 참담함
# 3  서울의 봄     3.9  "실패하면 반역, 성공하면 혁명 아닙니까?"\n\n그럼에도, 다시금 봄이 찾아왔기 ...
# 4  서울의 봄     3.9  거울 속 비친 전두광 자신의 모습이 어떠했을까 아주 잠깐일지 몰라도 분명 전두광의 ...
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-7-4c673116857e> in <cell line: 18>()
#      16
#      17 # Save the expanded dataframe to a new CSV file
# ---> 18 expanded_reviews_df.to_csv('/영화리뷰_왓챠피디아_확장.csv', index=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3770         )
#    3771
# -> 3772         return DataFrameRenderer(formatter).to_csv(
#    3773             path_or_buf,
#    3774             lineterminator=lineterminator,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1184             formatter=self.fmt,
#    1185         )
# -> 1186         csv_formatter.save()
#    1187
#    1188         if created_buffer:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in save(self)
#     257             )
#     258
# --> 259             self._save()
#     260
#     261     def _save(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save(self)
#     262         if self._need_to_save_header:
#     263             self._save_header()
# --> 264         self._save_body()
#     265
#     266     def _save_header(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_body(self)
#     300             if start_i >= end_i:
#     301                 break
# --> 302             self._save_chunk(start_i, end_i)
#     303
#     304     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     311
#     312         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 313         libwriters.write_csv_rows(
#     314             data,
#     315             ix,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# Error: need to escape, but no escapechar set

# %%
expanded_reviews_df.to_csv('/영화리뷰_왓챠피디아_확장.csv', index=False, escapechar='\\')

# %%
expanded_reviews_df
# Out:
#       title  rating                                            reviews
# 0     서울의 봄     3.9                                하아 대머리 죽었지만 다시 죽이고픔
# 1     서울의 봄     3.9       야만과 무능의 그 겨울밤에 대한 분노가 시종 팽팽한 긴장감 속에서 펄펄 끓는다.
# 2     서울의 봄     3.9                                   예정된 비극을 바라보는 참담함
# 3     서울의 봄     3.9  "실패하면 반역, 성공하면 혁명 아닙니까?"\n\n그럼에도, 다시금 봄이 찾아왔기 ...
# 4     서울의 봄     3.9  거울 속 비친 전두광 자신의 모습이 어떠했을까 아주 잠깐일지 몰라도 분명 전두광의 ...
# ...     ...     ...                                                ...
# 1231    엘비스     3.5  정신없는 초반부보다는 엘비스의 고독한 내면이 느껴지는 후반부로 갈수록 깊이 빠져든다...
# 1232    엘비스     3.5                               가슴 벅찬 포인트\n보기 벅찬 분량들
# 1233    엘비스     3.5  "노래가 없으면 변화도 없다." - Elvis Aaron Presley "엘비스 이...
# 1234    엘비스     3.5                                  별을 향한 탐닉, 증오, 중독.
# 1235    엘비스     3.5            진정 음악을 사랑한, 일찍 세상을 떠났지만 한 시대를 풍미했던 레전드.
#
# [1236 rows x 3 columns]

# %%
expanded_reviews_df['reviews'] = expanded_reviews_df['reviews'].apply(lambda x: x.replace('\n\n', ''))
expanded_reviews_df['reviews'] = expanded_reviews_df['reviews'].apply(lambda x: x.replace('\n', ''))

# %%
expanded_reviews_df
# Out:
#       title  rating                                            reviews
# 0     서울의 봄     3.9                                하아 대머리 죽었지만 다시 죽이고픔
# 1     서울의 봄     3.9       야만과 무능의 그 겨울밤에 대한 분노가 시종 팽팽한 긴장감 속에서 펄펄 끓는다.
# 2     서울의 봄     3.9                                   예정된 비극을 바라보는 참담함
# 3     서울의 봄     3.9  "실패하면 반역, 성공하면 혁명 아닙니까?"그럼에도, 다시금 봄이 찾아왔기 때문에그...
# 4     서울의 봄     3.9  거울 속 비친 전두광 자신의 모습이 어떠했을까 아주 잠깐일지 몰라도 분명 전두광의 ...
# ...     ...     ...                                                ...
# 1231    엘비스     3.5  정신없는 초반부보다는 엘비스의 고독한 내면이 느껴지는 후반부로 갈수록 깊이 빠져든다...
# 1232    엘비스     3.5                                 가슴 벅찬 포인트보기 벅찬 분량들
# 1233    엘비스     3.5  "노래가 없으면 변화도 없다." - Elvis Aaron Presley "엘비스 이...
# 1234    엘비스     3.5                                  별을 향한 탐닉, 증오, 중독.
# 1235    엘비스     3.5            진정 음악을 사랑한, 일찍 세상을 떠났지만 한 시대를 풍미했던 레전드.
#
# [1236 rows x 3 columns]

# %%
expanded_reviews_df.to_csv('/영화리뷰_왓챠피디아_확장.csv', index=False, escapechar='\\')

# %%
df_cine = pd.read_csv("씨네21.csv")
df_cine
# Out:
#      Unnamed: 0 movie_title running_time release_date       viewer  \
# 0             0    스트레인지 월드         101분   2022-11-23     112,910명
# 1             1     싱글 인 서울          NaN   2023-11-29     400,681명
# 2             2     싱글 인 서울          NaN   2023-11-29     400,681명
# 3             3     싱글 인 서울          NaN   2023-11-29     400,681명
# 4             4   아바타: 물의 길         192분   2022-12-14  10,805,065명
# ..          ...         ...          ...          ...          ...
# 674         674         더 문         129분   2023-08-02     486,060명
# 675         675         더 문         129분   2023-08-02     486,060명
# 676         676          타겟         101분   2023-08-30     424,916명
# 677         677          타겟         101분   2023-08-30     424,916명
# 678         678          타겟         101분   2023-08-30     424,916명
#
#          director                                             actors  \
# 0    돈 홀, 퀴 응우옌,   ['제이크 질렌할', '루시 리우', '데니스 퀘이드', '자부키 영-화이트', '...
# 1           박범수,                  ['이동욱', '임수정', '이솜', '장현성', '김지영']
# 2           박범수,                  ['이동욱', '임수정', '이솜', '장현성', '김지영']
# 3           박범수,                  ['이동욱', '임수정', '이솜', '장현성', '김지영']
# 4       제임스 카메론,                        ['조 샐다나', '샘 워싱턴', '시고니 위버']
# ..            ...                                                ...
# 674         김용화,   ['설경구', '도경수', '김희애', '박병은', '조한철', '최병모', '홍승희']
# 675         김용화,   ['설경구', '도경수', '김희애', '박병은', '조한철', '최병모', '홍승희']
# 676         박희곤,   ['신혜선', '김성균', '임철수', '이주영', '강태오', '임성재', '금새록']
# 677         박희곤,   ['신혜선', '김성균', '임철수', '이주영', '강태오', '임성재', '금새록']
# 678         박희곤,   ['신혜선', '김성균', '임철수', '이주영', '강태오', '임성재', '금새록']
#
#          production screenplay_writers director_of_photography editors  \
# 0               NaN          ['퀴 응우옌']                      []      []
# 1               NaN                 []                      []      []
# 2               NaN                 []                      []      []
# 3               NaN                 []                      []      []
# 4               NaN                 []                      []      []
# ..              ...                ...                     ...     ...
# 674  CJ ENM STUDIOS                 []                      []      []
# 675  CJ ENM STUDIOS                 []                      []      []
# 676             조병연     ['박희곤', '김동후']                      []      []
# 677             조병연     ['박희곤', '김동후']                      []      []
# 678             조병연     ['박희곤', '김동후']                      []      []
#
#     original_author       distributor          importer  review_count  \
# 0                []  ['월트디즈니컴퍼니코리아㈜']  ['월트디즈니컴퍼니코리아㈜']             0
# 1                []                []                []             3
# 2                []                []                []             3
# 3                []                []                []             3
# 4                []  ['월트디즈니컴퍼니코리아㈜']  ['월트디즈니컴퍼니코리아㈜']             4
# ..              ...               ...               ...           ...
# 674              []        ['CJ ENM']                []             3
# 675              []        ['CJ ENM']                []             3
# 676              []   ['플러스엠 엔터테인먼트']                []             3
# 677              []   ['플러스엠 엔터테인먼트']                []             3
# 678              []   ['플러스엠 엔터테인먼트']                []             3
#
#            review_id          review_date  review_rating  \
# 0                NaN                  NaN            NaN
# 1           filmone1  2023-12-28 23:40:47            6.0
# 2            thrill5  2023-12-27 19:54:55           10.0
# 3          hwachul92  2023-11-30 21:15:44            8.0
# 4           filmone1  2023-01-05 08:32:50            8.0
# ..               ...                  ...            ...
# 674        hwachul92  2023-08-02 21:54:28            8.0
# 675  263185326081682  2023-05-09 16:54:45           10.0
# 676         21457255  2024-02-04 20:19:55            6.0
# 677         filmone1  2023-09-19 00:37:52            5.0
# 678        hwachul92  2023-08-31 20:39:26            8.0
#
#                                         review_comment
# 0                                                  NaN
# 1    박범수 감독이 연출한 <싱글 인 서울>은 책을 출판하기 위해 함께하는 두 남녀의 사...
# 2    한국에서 청년층이 연애하지 않는 이유를 사회적인 제약으로만 생각하려는 \n\n경향이...
# 3    평범하면서 가을 느낌을 솔솔 풍기며 힐링을 주는 로맨틱코미디영화였습니다! 싱글을 전...
# 4    제임스 카메론 감독이 연출한 <아바타: 물의 길>은 13년 만에 제작된 <아바타>의...
# ..                                                 ...
# 674  달과 우주를 배경으로 긴장과 몰입 그리고 감동을 함께 선사한 SF영화였습니다! 한국...
# 675          Actor Doh Kyungsoo's big screen comeback!
# 676                       억울한 일을 당하는 역할은 서영희 이후 신혜선이 갑
# 677  박희곤 감독이 연출한 <타겟>은 중고거래 사기를 당한 여성이 복수를 하려다 벌어지는...
# 678  소름돋으면서 긴장감을 형성시킨 서스펜스범죄영화였습니다! 중고거래를 명목으로 사기 및...
#
# [679 rows x 19 columns]

# %%
df_cine = df_cine.loc[:,['movie_title','review_rating','review_comment']]

# %%
df_cine.columns = ['title', 'rating', 'reviews']

# %%
df_cine
# Out:
#          title  rating                                            reviews
# 0     스트레인지 월드     NaN                                                NaN
# 1      싱글 인 서울     6.0  박범수 감독이 연출한 <싱글 인 서울>은 책을 출판하기 위해 함께하는 두 남녀의 사...
# 2      싱글 인 서울    10.0  한국에서 청년층이 연애하지 않는 이유를 사회적인 제약으로만 생각하려는 \n\n경향이...
# 3      싱글 인 서울     8.0  평범하면서 가을 느낌을 솔솔 풍기며 힐링을 주는 로맨틱코미디영화였습니다! 싱글을 전...
# 4    아바타: 물의 길     8.0  제임스 카메론 감독이 연출한 <아바타: 물의 길>은 13년 만에 제작된 <아바타>의...
# ..         ...     ...                                                ...
# 674        더 문     8.0  달과 우주를 배경으로 긴장과 몰입 그리고 감동을 함께 선사한 SF영화였습니다! 한국...
# 675        더 문    10.0          Actor Doh Kyungsoo's big screen comeback!
# 676         타겟     6.0                       억울한 일을 당하는 역할은 서영희 이후 신혜선이 갑
# 677         타겟     5.0  박희곤 감독이 연출한 <타겟>은 중고거래 사기를 당한 여성이 복수를 하려다 벌어지는...
# 678         타겟     8.0  소름돋으면서 긴장감을 형성시킨 서스펜스범죄영화였습니다! 중고거래를 명목으로 사기 및...
#
# [679 rows x 3 columns]

# %%
expanded_reviews_df[expanded_reviews_df['title'] == ' 틀맨']['title'] = '젠틀맨'
# Out:
# <ipython-input-64-c8431bc1c87f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expanded_reviews_df[expanded_reviews_df['title'] == ' 틀맨']['title'] = '젠틀맨'

# %%
df_cine['reviews'] = df_cine['reviews'].astype(str)

# %%
df_cine['reviews'] = df_cine['reviews'].apply(lambda x: x.replace('\n\n', ''))
df_cine['reviews'] = df_cine['reviews'].apply(lambda x: x.replace('\n', ''))

# %%
df_cine.dropna(inplace = True)

# %%
df_cine.to_csv("영화리뷰_씨네21.csv", index = False)

# %%
watcha_titles = expanded_reviews_df['title'].unique()
filtered_cine21_df = df_cine[df_cine['title'].isin(watcha_titles)]

# %%
filtered_cine21_df = filtered_cine21_df.reset_index().drop('index', axis=1)

# %%
filtered_cine21_df
# Out:
#          title  rating                                            reviews
# 0      싱글 인 서울     6.0  박범수 감독이 연출한 <싱글 인 서울>은 책을 출판하기 위해 함께하는 두 남녀의 사...
# 1      싱글 인 서울    10.0  한국에서 청년층이 연애하지 않는 이유를 사회적인 제약으로만 생각하려는 경향이 강하다...
# 2      싱글 인 서울     8.0  평범하면서 가을 느낌을 솔솔 풍기며 힐링을 주는 로맨틱코미디영화였습니다! 싱글을 전...
# 3    아바타: 물의 길     8.0  제임스 카메론 감독이 연출한 <아바타: 물의 길>은 13년 만에 제작된 <아바타>의...
# 4    아바타: 물의 길    10.0  존재 자체로 각인되는 아바타 두 번째 이야기 ‘물의 길’은 감독 제임스 카메론의 본...
# ..         ...     ...                                                ...
# 471        더 문     8.0  달과 우주를 배경으로 긴장과 몰입 그리고 감동을 함께 선사한 SF영화였습니다! 한국...
# 472        더 문    10.0          Actor Doh Kyungsoo's big screen comeback!
# 473         타겟     6.0                       억울한 일을 당하는 역할은 서영희 이후 신혜선이 갑
# 474         타겟     5.0  박희곤 감독이 연출한 <타겟>은 중고거래 사기를 당한 여성이 복수를 하려다 벌어지는...
# 475         타겟     8.0  소름돋으면서 긴장감을 형성시킨 서스펜스범죄영화였습니다! 중고거래를 명목으로 사기 및...
#
# [476 rows x 3 columns]

# %%
reviews_df = pd.concat([expanded_reviews_df, filtered_cine21_df], axis=0)

# %%
reviews_df.sort_values(by='title', inplace=True)
reviews_df.reset_index(inplace=True)

# %%
reviews_df[reviews_df['title'] == ' 틀맨']
# Out:
#    index title  rating                                            reviews
# 0    921    틀맨     3.0  하는 짓이 하도 답답해서 로맨스 빼고 보니까 갑자기 이해됨 뭐지??? 이마를 탁쳤다...
# 1    920    틀맨     3.0            걍... 부잣집 브리저튼 둘째 셋째 아들내미들팔자가 제일 부러움....
# 2    919    틀맨     3.0                               다프네가 갓캐였다.. 무매력인 형제들
# 3    918    틀맨     3.0  둘의 케미는 좋은데 7화까지 고구마먹다가 겨우 이뤄진다. 진도가 너무 안나감... ...
# 4    917    틀맨     3.0                  구레나룻 좀 잘랐다고 이렇게 핫해져도 되는 거임? 앤소니도?
# 5    916    틀맨     3.0  - 아주 귀엽고 쌔끈하고 콩닥거리고 다 했던 시즌1과는 비교조차 안됨. 일단 남녀주...
# 6    915    틀맨     3.0                            다프네 결혼 생활이 더 궁금한 거부터 문제
# 7    914    틀맨     3.0                               성매매boy가 무슨 결혼이야 뒤질려고
