# %% [markdown]
# <a href="https://colab.research.google.com/github/Tiabet/Python_Study/blob/master/Movie_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("영화_최종데이터.csv")

# %%
df
# Out:
#          Movie        Date   Total Sales  Sales Share  Cumulative Sales  \
# 0        서울의 봄  2023-11-22  127926589712        0.051      127926589712
# 1        범죄도시2  2022-05-18  129317928648        0.052      131298796478
# 2           파묘  2024-02-22  115063079635        0.046      115063079635
# 3    아바타: 물의 길  2022-12-14  137647702899        0.055      137647702899
# 4        범죄도시3  2023-05-31  104687737771        0.042      104687737771
# ..         ...         ...           ...          ...               ...
# 158        블랙폰  2022-09-07    1085449042        0.000        1085449042
# 159        스마일  2022-10-06    1124306658        0.000        1124306658
# 160       뉴 노멀  2023-11-08     987958873        0.000         987958873
# 161        비키퍼  2024-04-03     962290905        0.000         962290905
# 162        엘비스  2022-07-13    1098745318        0.000        1098745318
#
#      Total Attendance  Cumulative Attendance  Screen Count  Show Count  \
# ...

# %%
df.columns
# Out:
# Index(['Movie', 'Date', 'Total Sales', 'Sales Share', 'Cumulative Sales',
#        'Total Attendance', 'Cumulative Attendance', 'Screen Count',
#        'Show Count', 'Country', 'Production Country', 'Production Company',
#        'Distributor', 'Level', 'Director', 'Production Budgets', 'Success',
#        'actor1', 'actor2', 'actor3', 'genre1', 'genre2', 'rating', 'sentiment',
#        'YearMonth', '남자 인구수', '여자 인구수', '총인구수', '가계지출', '소비지출', '비소비지출',
#        'ViewCount', 'LikeCount'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Movie                     0
# Date                      0
# Total Sales               0
# Sales Share               0
# Cumulative Sales          0
# Total Attendance          0
# Cumulative Attendance     0
# Screen Count              0
# Show Count                0
# Country                   0
# Production Country        0
# Production Company       81
# Distributor               0
# Level                     0
# Director                  5
# Production Budgets        0
# Success                   0
# actor1                   15
# actor2                   18
# actor3                   27
# genre1                    0
# genre2                   89
# rating                    3
# sentiment                 3
# YearMonth                 0
# 남자 인구수                    2
# 여자 인구수                    2
# 총인구수                      2
# 가계지출                     29
# 소비지출                     29
# 비소비지출                    29
# ViewCount                 3
# LikeCount                 3
# ...

# %%
df[df['rating']>5]
# Out:
#            Movie        Date  Total Sales  Sales Share  Cumulative Sales  \
# 9    공조2 : 인터내셔널  2022-09-07  70918411586        0.028       70918411586
# 40             잠  2023-09-06  13894258933        0.006       13894258933
# 160         뉴 노멀  2023-11-08    987958873        0.000         987958873
#
#      Total Attendance  Cumulative Attendance  Screen Count  Show Count  \
# 9             6983077                6983077          2389      275817
# 40            1470359                1470359          1231      103697
# 160            103037                 103037           546       10934
#
#     Country  ... sentiment YearMonth      남자 인구수      여자 인구수        총인구수  \
# 9        한국  ...      64.0   2022.09  25653998.0  25812660.0  51466658.0
# 40       한국  ...      77.8   2023.09  25592335.0  25777666.0  51370001.0
# 160      한국  ...      75.5   2023.11  25572695.0  25764381.0  51337076.0
#
#        가계지출    소비지출  비소비지출  ViewCount LikeCount
# ...

# %%
df[df['rating']>5]['rating']
# Out:
# 9      7.20
# 40     8.00
# 160    7.75
# Name: rating, dtype: float64

# %%
df.loc[9,'rating'] = 3.35
df.loc[40,'rating'] = 3.65
df.loc[160,'rating'] =  3.05

# %%
df['rating'] = df['rating'].fillna(df['rating'].mean())

# %%
df['sentiment'] = df['sentiment'].fillna(df['sentiment'].mean())

# %%
df.to_csv('영화_최종데이터_v2.csv',index=False)

# %%
tmp = pd.read_csv('actor_genre_pp.csv')

# %%
tmp
# Out:
#          Movie        Date   Total Sales  Sales Share  Cumulative Sales  \
# 0        서울의 봄  2023-11-22  127926589712        0.051      127926589712
# 1        범죄도시2  2022-05-18  129317928648        0.052      131298796478
# 2           파묘  2024-02-22  115063079635        0.046      115063079635
# 3    아바타: 물의 길  2022-12-14  137647702899        0.055      137647702899
# 4        범죄도시3  2023-05-31  104687737771        0.042      104687737771
# ..         ...         ...           ...          ...               ...
# 158        블랙폰  2022-09-07    1085449042        0.000        1085449042
# 159        스마일  2022-10-06    1124306658        0.000        1124306658
# 160       뉴 노멀  2023-11-08     987958873        0.000         987958873
# 161        비키퍼  2024-04-03     962290905        0.000         962290905
# 162        엘비스  2022-07-13    1098745318        0.000        1098745318
#
#      Total Attendance  Cumulative Attendance  Screen Count  Show Count  \
# ...

# %%
df = tmp

# %%
df.loc[9,'rating'] = 3.35
df.loc[40,'rating'] = 3.65
df.loc[160,'rating'] =  3.05

df['rating'] = df['rating'].fillna(df['rating'].mean())

df['sentiment'] = df['sentiment'].fillna(df['sentiment'].mean())

# %%
df.to_csv('영화_최종데이터_v3.csv',index=False)

# %% [markdown]
# 여기서부터 상관계수 분석

# %%
df.isna().sum()
# Out:
# Movie                     0
# Date                      0
# Total Sales               0
# Sales Share               0
# Cumulative Sales          0
# Total Attendance          0
# Cumulative Attendance     0
# Screen Count              0
# Show Count                0
# Country                   0
# Production Country        0
# Production Company       81
# Distributor               0
# Level                     0
# Director                  5
# Production Budgets        0
# Success                   0
# actor1                   15
# actor2                   18
# actor3                   27
# genre1                    0
# genre2                   89
# rating                    0
# sentiment                 0
# YearMonth                 0
# 남자 인구수                    2
# 여자 인구수                    2
# 총인구수                      2
# 가계지출                     29
# 소비지출                     29
# 비소비지출                    29
# ViewCount                 3
# LikeCount                 3
# ...

# %%
import pandas as pd

df = pd.read_csv("영화_최종데이터_v3.csv")

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
import matplotlib.font_manager as fm
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings(action='ignore')
path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf' # 나눔 고딕
font_name = fm.FontProperties(fname=path, size=10).get_name() # 기본 폰트 사이즈 : 10
plt.rc('font', family=font_name)

# %%
import seaborn as sns

selected_columns_for_analysis = [
    'sentiment','rating','ViewCount', 'LikeCount', 'Actor1', 'Actor2', 'Actor3', 'GENRE1', 'GENRE2',
    '남자 인구수', '여자 인구수', '총인구수', '가계지출', '소비지출', '비소비지출', 'Total Sales'
]

data_filled = df[selected_columns_for_analysis].fillna(df[selected_columns_for_analysis].mean())

correlation_matrix_filtered = data_filled.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix_filtered, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix with Success Metrics')
plt.show()
