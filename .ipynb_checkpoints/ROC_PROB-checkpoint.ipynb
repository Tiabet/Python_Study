# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression  # Replace with your model

# Assuming you have predicted probabilities (pred_probs) and true labels (true_labels)
# Replace this with your actual predicted probabilities and true labels
pred_probs = np.random.rand(1000)
true_labels = np.random.randint(2, size=1000)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(pred_probs, true_labels, test_size=0.2, random_state=42)

# Train your model (replace this with your actual model training)
# For example, using Logistic Regression
model = LogisticRegression()
model.fit(X_train.reshape(-1, 1), y_train)

# Get predicted probabilities for the test set
pred_probs_test = model.predict_proba(X_test.reshape(-1, 1))[:, 1]

# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, pred_probs_test)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
thresholds
# Out:
# array([1.5264903 , 0.5264903 , 0.52644538, 0.52614762, 0.52614204,
#        0.52611491, 0.5259183 , 0.52591528, 0.52579189, 0.52570409,
#        0.52525623, 0.52519777, 0.52500153, 0.52488939, 0.52483279,
#        0.52475187, 0.52471734, 0.52470375, 0.52450141, 0.52426976,
#        0.52420096, 0.52389388, 0.52386563, 0.52377094, 0.52374977,
#        0.52338237, 0.52329338, 0.5229955 , 0.52263941, 0.5223662 ,
#        0.52231632, 0.52227694, 0.52221344, 0.52209312, 0.52207298,
#        0.52202264, 0.52198306, 0.5217137 , 0.52163068, 0.52147342,
#        0.5214474 , 0.52090361, 0.52069165, 0.52057812, 0.52033785,
#        0.52026754, 0.52022134, 0.52021192, 0.52014115, 0.51983679,
#        0.51982297, 0.51974621, 0.51961554, 0.5194547 , 0.5194494 ,
#        0.51934959, 0.5191733 , 0.51866286, 0.51864953, 0.5185594 ,
#        0.51855166, 0.51822532, 0.51822236, 0.51817427, 0.51813565,
#        0.51803908, 0.51797864, 0.51796743, 0.51787419, 0.51770804,
# ...

# %%
len(pred_probs_test)
# Out:
# 200
