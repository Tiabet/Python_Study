# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/sehakflower/data/main/titanic.csv'
titanic_df=pd.read_csv(url,sep='\t')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 151      0            113776  66.6000    C2        S
# 152      0        A.5. 11206   8.0500   NaN        S
# 153      2          A/5. 851  14.5000   NaN        S
# 154      0         Fa 265302   7.3125   NaN        S
# 155      1          PC 17597  61.3792   NaN        C
#
# [156 rows x 12 columns]

# %%
titanic_df.shape
# Out:
# (156, 12)

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
titanic_df.info( )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          126 non-null    float64
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float64
#  10  Cabin        31 non-null     object
#  11  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.8+ KB

# %%
new_columns=['passengerId', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch',
'ticket', 'fare', 'cabin', 'embarked']
titanic_df.columns=new_columns
titanic_df.columns
# Out:
# Index(['passengerId', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
titanic_df
# Out:
#      passengerId  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      parch            ticket     fare cabin embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 151      0            113776  66.6000    C2        S
# 152      0        A.5. 11206   8.0500   NaN        S
# 153      2          A/5. 851  14.5000   NaN        S
# 154      0         Fa 265302   7.3125   NaN        S
# 155      1          PC 17597  61.3792   NaN        C
#
# [156 rows x 12 columns]

# %%
copy_titanic_df = titanic_df.copy()

# %%
copy_titanic_df['gender']=1
copy_titanic_df.tail( )
# Out:
#      passengerId  survived  pclass                               name     sex  \
# 151          152         1       1  Pears, Mrs. Thomas (Edith Wearne)  female
# 152          153         0       3                   Meo, Mr. Alfonzo    male
# 153          154         0       3    van Billiard, Mr. Austin Blyler    male
# 154          155         0       3              Olsen, Mr. Ole Martin    male
# 155          156         0       1        Williams, Mr. Charles Duane    male
#
#       age  sibsp  parch      ticket     fare cabin embarked  gender
# 151  22.0      1      0      113776  66.6000    C2        S       1
# 152  55.5      0      0  A.5. 11206   8.0500   NaN        S       1
# 153  40.5      0      2    A/5. 851  14.5000   NaN        S       1
# 154   NaN      0      0   Fa 265302   7.3125   NaN        S       1
# 155  51.0      0      1    PC 17597  61.3792   NaN        C       1

# %%
copy_titanic_df.loc[copy_titanic_df['sex']=='female', 'gender']=0
copy_titanic_df.head( )
# Out:
#    passengerId  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked  gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# 4      0            373450   8.0500   NaN        S       1

# %%
copy_titanic_df.iloc[3:5,4]
#iloc 사용할 땐 column name 말고 column index로
# Out:
# 3    female
# 4      male
# Name: sex, dtype: object

# %%
copy_titanic_df.loc[3:5,'sex']
#loc에선 3:5에서 5까지도 포함한다.
# Out:
# 3    female
# 4      male
# 5      male
# Name: sex, dtype: object

# %%
titanic_df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [154, 0, 3, ..., 14.5, nan, 'S'],
#        [155, 0, 3, ..., 7.3125, nan, 'S'],
#        [156, 0, 1, ..., 61.3792, nan, 'C']], dtype=object)

# %%
titanic_df.loc[0]
# Out:
# passengerId                          1
# survived                             0
# pclass                               3
# name           Braund, Mr. Owen Harris
# sex                               male
# age                               22.0
# sibsp                                1
# parch                                0
# ticket                       A/5 21171
# fare                              7.25
# cabin                              NaN
# embarked                             S
# Name: 0, dtype: object

# %%
titanic_df.sort_values(by='age') # 오름차순 정렬
titanic_df.sort_values(by='age', ascending=False) # 내림차순 정렬

# %%
titanic_df[::3] #3칸씩 띄어서
# ::은 열을 어떻게 조작하라는 의미를 가짐
titanic_df[::-1] #거꾸로 출력
titanic_df[::-2] #거꾸로 2칸씩 띄어서

# %%
titanic_df[titanic_df.columns[11]]

# %%
titanic_df.columns

# %%
titanic_df['age']

# %%
titanic_df[[titanic_df.columns[2],titanic_df.columns[3],titanic_df.columns[4]]][2:15:3] 
#띄는 칸수를 지정하려면 : 한 번 더 사용

# %%
titanic_df.loc[1:11:2]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 5             6         0       3
# 7             8         0       3
# 9            10         1       2
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                    Moran, Mr. James    male   NaN      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 5       0    330877   8.4583   NaN        Q
# 7       1    349909  21.0750   NaN        S
# 9       0    237736  30.0708   NaN        C
# 11      0    113783  26.5500  C103        S

# %%
titanic_df.iloc[1:11:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
# 5            6         0       3
# 7            8         0       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                   Moran, Mr. James    male   NaN      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C
# 3      0    113803  53.1000  C123        S
# 5      0    330877   8.4583   NaN        Q
# 7      1    349909  21.0750   NaN        S
# 9      0    237736  30.0708   NaN        C

# %%
titanic_df.iloc[3:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#    Ticket   Fare Cabin Embarked
# 3  113803  53.10  C123        S
# 4  373450   8.05   NaN        S

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 151      0            113776  66.6000    C2        S
# 152      0        A.5. 11206   8.0500   NaN        S
# 153      2          A/5. 851  14.5000   NaN        S
# 154      0         Fa 265302   7.3125   NaN        S
# 155      1          PC 17597  61.3792   NaN        C
#
# [156 rows x 12 columns]

# %%
titanic_df.loc[:, ['age', 'sex']]
# Out:
#       age     sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 151  22.0  female
# 152  55.5    male
# 153  40.5    male
# 154   NaN    male
# 155  51.0    male
#
# [156 rows x 2 columns]

# %%
titanic_df.loc[2:5, 'survived':'age'] #:기호는 행과 열 모두에 사용 가능
# Out:
#    survived  pclass                                          name     sex  \
# 2         1       3                        Heikkinen, Miss. Laina  female
# 3         1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4         0       3                      Allen, Mr. William Henry    male
# 5         0       3                              Moran, Mr. James    male
#
#     age
# 2  26.0
# 3  35.0
# 4  35.0
# 5   NaN

# %%
titanic_df.iloc[1:5, [0, 2]]
# Out:
#    passengerId  pclass
# 1            2       1
# 2            3       3
# 3            4       1
# 4            5       3

# %%
titanic_df.pivot_table(index='pclass', columns='sex', values='survived')
# Out:
# sex       female      male
# pclass
# 1       1.000000  0.142857
# 2       0.916667  0.166667
# 3       0.571429  0.131148

# %%
import numpy as np # mean 함수를 사용하기 위해 numpy를 import
titanic_df.pivot_table(index='pclass', columns='sex', values='survived', aggfunc=np.sum) #affunc의 디폴트는 mean
# Out:
# sex     female  male
# pclass
# 1            9     3
# 2           11     3
# 3           20     8

# %%
titanic_df2 = titanic_df[['pclass','age','sibsp','survived','sex']]

# %%
titanic_df2
# Out:
#      pclass   age  sibsp  survived     sex
# 0         3  22.0      1         0    male
# 1         1  38.0      1         1  female
# 2         3  26.0      0         1  female
# 3         1  35.0      1         1  female
# 4         3  35.0      0         0    male
# ..      ...   ...    ...       ...     ...
# 151       1  22.0      1         1  female
# 152       3  55.5      0         0    male
# 153       3  40.5      0         0    male
# 154       3   NaN      0         0    male
# 155       1  51.0      0         0    male
#
# [156 rows x 5 columns]

# %%
df = titanic_df2.groupby(['sex', 'survived']).mean()
df
# Out:
#                    pclass        age     sibsp
# sex    survived
# female 0         2.937500  20.633333  1.437500
#        1         2.275000  26.265625  0.650000
# male   0         2.406977  31.228571  0.523256
#        1         2.357143  23.314444  0.142857

# %%
df.unstack('sex')
# Out:
#           pclass                  age              sibsp
# sex       female      male     female       male  female      male
# survived
# 0         2.9375  2.406977  20.633333  31.228571  1.4375  0.523256
# 1         2.2750  2.357143  26.265625  23.314444  0.6500  0.142857

# %%
df.unstack('survived')
# Out:
#             pclass                  age                sibsp
# survived         0         1          0          1         0         1
# sex
# female    2.937500  2.275000  20.633333  26.265625  1.437500  0.650000
# male      2.406977  2.357143  31.228571  23.314444  0.523256  0.142857

# %%
df = df.unstack('survived')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18012\2680798136.py in <module>
# ----> 1 df = df.unstack('survived')
#       2 df
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in unstack(self, level, fill_value)
#    8959         from pandas.core.reshape.reshape import unstack
#    8960
# -> 8961         result = unstack(self, level, fill_value)
#    8962
#    8963         return result.__finalize__(self, method="unstack")
#
# C:\Anaconda\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     469     if not is_integer(level) and not level == "__placeholder__":
#     470         # check if level is valid in case of regular index
# --> 471         obj.index._get_level_number(level)
#     472
#     473     if isinstance(obj, DataFrame):
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in _get_level_number(self, level)
#    1913
#    1914     def _get_level_number(self, level) -> int:
# -> 1915         self._validate_index_level(level)
#    1916         return 0
#    1917
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1908                 )
#    1909         elif level != self.name:
# -> 1910             raise KeyError(
#    1911                 f"Requested level ({level}) does not match index name ({self.name})"
#    1912             )
#
# KeyError: 'Requested level (survived) does not match index name (sex)'

# %%
df
# Out:
#             pclass                  age                sibsp
# survived         0         1          0          1         0         1
# sex
# female    2.937500  2.275000  20.633333  26.265625  1.437500  0.650000
# male      2.406977  2.357143  31.228571  23.314444  0.523256  0.142857

# %%
df = df.stack('survived')

# %%
df
# Out:
#                    pclass        age     sibsp
# sex    survived
# female 0         2.937500  20.633333  1.437500
#        1         2.275000  26.265625  0.650000
# male   0         2.406977  31.228571  0.523256
#        1         2.357143  23.314444  0.142857

# %%
import pandas as pd
url='https://github.com/sehakflower/data/blob/main/titanic_1309.xlsx?raw=true'
titanic=pd.read_excel(url, sheet_name='total')
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
train_1000=titanic.iloc[:1000]
test_309=titanic.iloc[1000:]
len(train_1000), len(test_309)
# Out:
# (1000, 309)

# %%
total_df=pd.concat([train_1000, test_309]) # 옵션 없으면 axis=0
total_df=pd.concat([train_1000, test_309], axis=0) # 위아래로 붙일 때는 axis=0
total_df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
total_df=pd.concat([train_1000, test_309])
total_df=pd.concat([train_1000, test_309], axis=1)
total_df.columns.unique()
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df1=train_1000[['name', 'pclass', 'sex', 'age']]
df1
# Out:
#                                                 name  pclass     sex      age
# 0                      Allen, Miss. Elisabeth Walton       1  female  29.0000
# 1                     Allison, Master. Hudson Trevor       1    male   0.9167
# 2                       Allison, Miss. Helen Loraine       1  female   2.0000
# 3               Allison, Mr. Hudson Joshua Creighton       1    male  30.0000
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  female  25.0000
# ..                                               ...     ...     ...      ...
# 995                               Markoff, Mr. Marin       3    male  35.0000
# 996                               Markun, Mr. Johann       3    male  33.0000
# 997                          Masselmani, Mrs. Fatima       3  female      NaN
# 998                             Matinoff, Mr. Nicola       3    male      NaN
# 999                McCarthy, Miss. Catherine "Katie"       3  female      NaN
#
# [1000 rows x 4 columns]

# %%
df2=train_1000[['name', 'survived', 'age']]
df2
# Out:
#                                                 name  survived      age
# 0                      Allen, Miss. Elisabeth Walton         1  29.0000
# 1                     Allison, Master. Hudson Trevor         1   0.9167
# 2                       Allison, Miss. Helen Loraine         0   2.0000
# 3               Allison, Mr. Hudson Joshua Creighton         0  30.0000
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)         0  25.0000
# ..                                               ...       ...      ...
# 995                               Markoff, Mr. Marin         0  35.0000
# 996                               Markun, Mr. Johann         0  33.0000
# 997                          Masselmani, Mrs. Fatima         1      NaN
# 998                             Matinoff, Mr. Nicola         0      NaN
# 999                McCarthy, Miss. Catherine "Katie"         1      NaN
#
# [1000 rows x 3 columns]

# %%
merge_inner=pd.merge(df1, df2)
merge_inner
#merge 쓰면 겹치는 열 제외하고 알아서 합쳐줌
# Out:
#                                                 name  pclass     sex      age  \
# 0                      Allen, Miss. Elisabeth Walton       1  female  29.0000
# 1                     Allison, Master. Hudson Trevor       1    male   0.9167
# 2                       Allison, Miss. Helen Loraine       1  female   2.0000
# 3               Allison, Mr. Hudson Joshua Creighton       1    male  30.0000
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  female  25.0000
# ..                                               ...     ...     ...      ...
# 995                               Markoff, Mr. Marin       3    male  35.0000
# 996                               Markun, Mr. Johann       3    male  33.0000
# 997                          Masselmani, Mrs. Fatima       3  female      NaN
# 998                             Matinoff, Mr. Nicola       3    male      NaN
# 999                McCarthy, Miss. Catherine "Katie"       3  female      NaN
#
#      survived
# 0           1
# 1           1
# 2           0
# 3           0
# 4           0
# ..        ...
# 995         0
# 996         0
# 997         1
# 998         0
# 999         1
#
# [1000 rows x 5 columns]

# %%
df2.loc[[0,2,3], ['name']] = ''
df2=df2[:10]
df1=df1[:10]
merge_inner=pd.merge(df1, df2, how='inner', on='name')
merge_inner
#inner : 겹치는 거만 합쳐줌
# Out:
#                                               name  pclass     sex    age_x  \
# 0                   Allison, Master. Hudson Trevor       1    male   0.9167
# 1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  female  25.0000
# 2                              Anderson, Mr. Harry       1    male  48.0000
# 3                Andrews, Miss. Kornelia Theodosia       1  female  63.0000
# 4                           Andrews, Mr. Thomas Jr       1    male  39.0000
# 5    Appleton, Mrs. Edward Dale (Charlotte Lamson)       1  female  53.0000
# 6                          Artagaveytia, Mr. Ramon       1    male  71.0000
#
#    survived    age_y
# 0         1   0.9167
# 1         0  25.0000
# 2         1  48.0000
# 3         1  63.0000
# 4         0  39.0000
# 5         1  53.0000
# 6         0  71.0000

# %%
merge_outer = pd.merge(df1,df2, how='outer',on='name')
merge_outer
#outer : 데이터 없는건 nan처리해서 합쳐줌
# Out:
#                                                name  pclass     sex    age_x  \
# 0                     Allen, Miss. Elisabeth Walton     1.0  female  29.0000
# 1                    Allison, Master. Hudson Trevor     1.0    male   0.9167
# 2                      Allison, Miss. Helen Loraine     1.0  female   2.0000
# 3              Allison, Mr. Hudson Joshua Creighton     1.0    male  30.0000
# 4   Allison, Mrs. Hudson J C (Bessie Waldo Daniels)     1.0  female  25.0000
# 5                               Anderson, Mr. Harry     1.0    male  48.0000
# 6                 Andrews, Miss. Kornelia Theodosia     1.0  female  63.0000
# 7                            Andrews, Mr. Thomas Jr     1.0    male  39.0000
# 8     Appleton, Mrs. Edward Dale (Charlotte Lamson)     1.0  female  53.0000
# 9                           Artagaveytia, Mr. Ramon     1.0    male  71.0000
# 10                                                      NaN     NaN      NaN
# 11                                                      NaN     NaN      NaN
# 12                                                      NaN     NaN      NaN
#
#     survived    age_y
# 0        NaN      NaN
# 1        1.0   0.9167
# 2        NaN      NaN
# 3        NaN      NaN
# 4        0.0  25.0000
# 5        1.0  48.0000
# 6        1.0  63.0000
# 7        0.0  39.0000
# 8        1.0  53.0000
# 9        0.0  71.0000
# 10       1.0  29.0000
# 11       0.0   2.0000
# 12       0.0  30.0000

# %%
merge_left=pd.merge(df1, df2, how='right', left_on='name', right_on='name')
merge_left 
#left, right : 두 개의 데이터프레임 중 왼쪽이냐 오른쪽이냐 기준을 정함
# Out:
#                                               name  pclass     sex    age_x  \
# 0                                                      NaN     NaN      NaN
# 1                   Allison, Master. Hudson Trevor     1.0    male   0.9167
# 2                                                      NaN     NaN      NaN
# 3                                                      NaN     NaN      NaN
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)     1.0  female  25.0000
# 5                              Anderson, Mr. Harry     1.0    male  48.0000
# 6                Andrews, Miss. Kornelia Theodosia     1.0  female  63.0000
# 7                           Andrews, Mr. Thomas Jr     1.0    male  39.0000
# 8    Appleton, Mrs. Edward Dale (Charlotte Lamson)     1.0  female  53.0000
# 9                          Artagaveytia, Mr. Ramon     1.0    male  71.0000
#
#    survived    age_y
# 0         1  29.0000
# 1         1   0.9167
# 2         0   2.0000
# 3         0  30.0000
# 4         0  25.0000
# 5         1  48.0000
# 6         1  63.0000
# 7         0  39.0000
# 8         1  53.0000
# 9         0  71.0000

# %%
df1.set_index('name', inplace=True)
df2.set_index('name', inplace=True)

# %%
df1
# Out:
#                                                  pclass     sex      age
# name
# Allen, Miss. Elisabeth Walton                         1  female  29.0000
# Allison, Master. Hudson Trevor                        1    male   0.9167
# Allison, Miss. Helen Loraine                          1  female   2.0000
# Allison, Mr. Hudson Joshua Creighton                  1    male  30.0000
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  female  25.0000
# Anderson, Mr. Harry                                   1    male  48.0000
# Andrews, Miss. Kornelia Theodosia                     1  female  63.0000
# Andrews, Mr. Thomas Jr                                1    male  39.0000
# Appleton, Mrs. Edward Dale (Charlotte Lamson)         1  female  53.0000
# Artagaveytia, Mr. Ramon                               1    male  71.0000

# %%
df2
# Out:
#                                                  survived      age
# name
#                                                         1  29.0000
# Allison, Master. Hudson Trevor                          1   0.9167
#                                                         0   2.0000
#                                                         0  30.0000
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)         0  25.0000
# Anderson, Mr. Harry                                     1  48.0000
# Andrews, Miss. Kornelia Theodosia                       1  63.0000
# Andrews, Mr. Thomas Jr                                  0  39.0000
# Appleton, Mrs. Edward Dale (Charlotte Lamson)           1  53.0000
# Artagaveytia, Mr. Ramon                                 0  71.0000

# %%
df1.join(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18012\1440473144.py in <module>
# ----> 1 df1.join(df2)
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9727         5  K1  A5   B1
#    9728         """
# -> 9729         return self._join_compat(
#    9730             other,
#    9731             on=on,
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9766                     validate=validate,
#    9767                 )
# -> 9768             return merge(
#    9769                 self,
#    9770                 other,
#
# C:\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     160         validate=validate,
#     161     )
# --> 162     return op.get_result(copy=copy)
#     163
#     164
#
# C:\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in get_result(self, copy)
#     809         join_index, left_indexer, right_indexer = self._get_join_info()
#     810
# --> 811         result = self._reindex_and_concat(
#     812             join_index, left_indexer, right_indexer, copy=copy
#     813         )
#
# C:\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in _reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     761         right = self.right[:]
#     762
# --> 763         llabels, rlabels = _items_overlap_with_suffix(
#     764             self.left._info_axis, self.right._info_axis, self.suffixes
#     765         )
#
# C:\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2602
#    2603     if not lsuffix and not rsuffix:
# -> 2604         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2605
#    2606     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['age'], dtype='object')

# %%
# Out:
#                                                  pclass     sex      age
# name
# Allen, Miss. Elisabeth Walton                         1  female  29.0000
# Allison, Master. Hudson Trevor                        1    male   0.9167
# Allison, Miss. Helen Loraine                          1  female   2.0000
# Allison, Mr. Hudson Joshua Creighton                  1    male  30.0000
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  female  25.0000
# Anderson, Mr. Harry                                   1    male  48.0000
# Andrews, Miss. Kornelia Theodosia                     1  female  63.0000
# Andrews, Mr. Thomas Jr                                1    male  39.0000
# Appleton, Mrs. Edward Dale (Charlotte Lamson)         1  female  53.0000
# Artagaveytia, Mr. Ramon                               1    male  71.0000
